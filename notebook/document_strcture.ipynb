# %% [markdown]
# Data Injestion

# %%
from langchain_community.document_loaders import PyMuPDFLoader, PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_core.documents import Document
import os

# %%
doc=Document(
    page_content="This is a sample document created using langchain.",
    metadata={
        "author":"John Doe",
        "title":"Sample Document",
        "created_at":"2024-06-01",
    }

)
doc
# Out:
# Document(metadata={'author': 'John Doe', 'title': 'Sample Document', 'created_at': '2024-06-01'}, page_content='This is a sample document created using langchain.')

# %%
from langchain_community.document_loaders import PyMuPDFLoader, PyPDFLoader,DirectoryLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_core.documents import Document
import os

loader=DirectoryLoader("../data", glob="**/*.pdf", show_progress=True, loader_cls=PyMuPDFLoader)
documents=loader.load()
print(f"Loaded {len(documents)} documents.")
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 303.71it/s]
# Loaded 5 documents.
